# %%
from tree_sitter import Language, Parser
from ranking.util import json_lines as jl
from ranking.util import dataset_paths as dp
from tqdm import tqdm
import pandas as pd

Language.build_library(
  # Store the library in the `build` directory
  'build/my-languages.so',

  # Include one or more languages
  [
    'bindings\\tree-sitter-haskell'
  ]
)

HS_LANGUAGE = Language('build\\my-languages.so', 'haskell')
parser = Parser()
parser.set_language(HS_LANGUAGE)

# %%
def contains_sig(text: str) -> bool:
    tree = parser.parse(bytes(text, "utf8"))
    return not tree.root_node.has_error and tree.root_node.children[0].type == 'signature'

# %%
def get_sig_type(sig: str, query) -> str:
    tree = parser.parse(bytes(sig, "utf8"))
    assert(tree.root_node.children[0].type == 'signature')
    captures = query.captures(tree.root_node)
    return str(captures[0][0].text, 'UTF-8')

# %%
dump = jl.read_jsonl('no-sig-check-raw.complete.dump.jsonl')
# dump = jl.read_jsonl(dp.unique_functions_corpus)

# %%
tqdm.pandas(desc='Progress')
dump['is_signature'] = dump['docItem'].progress_apply(contains_sig)
# Out:
# Progress: 100%|██████████| 805414/805414 [00:31<00:00, 25553.28it/s]

# %%
signatures = dump[dump['is_signature'] == True]
signatures
# print(len(signatures))
# print(signatures['docItem'].str.cat(sep='\n'))
# signatures[signatures['docItem'].str.split('() =>', regex=False).str.len() > 2]
# tqdm.pandas(desc='Progress')
# signatures['docType'] = ':: ' + signatures['docItem'].progress_apply(get_sig_type)
# Out:
#             docId                                         docContent  \
# 6             978                 Convert from radians to degrees.\n
# 7            1155                 Convert from degrees to radians.\n
# 9            1480
# 10           1634
# 11           1789
# ...           ...                                                ...
# 793115  176219740  Show all variables and equations. Useful in co...
# 793117  176220217
# 793118  176220406  Return the result of solving the equations or ...
# 793119  176220645  Run the solver and return the dependencies or ...
# 793120  176220880  Return the result of solving the equations, or...
#
#                                                   docItem docType docPackage  \
# 6         degrees :: Floating x => Radians x -> Degrees x           AC-Angle
# 7         radians :: Floating x => Degrees x -> Radians x           AC-Angle
# 9               sine :: (Angle a, Floating x) => a x -> x           AC-Angle
# 10            cosine :: (Angle a, Floating x) => a x -> x           AC-Angle
# 11           tangent :: (Angle a, Floating x) => a x -> x           AC-Angle
# ...                                                   ...     ...        ...
# 793115  showVars :: (Show n, Show v, Ord n, Ord v, Flo...            mfsolve
# 793117  runSolverT :: MFSolverT v n m a -> Dependencie...            mfsolve
# 793118  evalSolverT :: Functor f => MFSolverT v n f b ...            mfsolve
# 793119  execSolverT :: Functor m => MFSolverT v n m a ...            mfsolve
# 793120  unsafeSolveT :: (Num n, Ord n, Show n, Show v,...            mfsolve
#
#         is_signature
# 6               True
# 7               True
# 9               True
# 10              True
# 11              True
# ...              ...
# 793115          True
# 793117          True
# 793118          True
# 793119          True
# 793120          True
#
# [470571 rows x 6 columns]

# %%
# tree = parser.parse(bytes('(#%%=) :: MonadState s m => ALens s s a b -> (a -> (r, b)) -> m r', "utf8"))
print(len(signatures))
query = HS_LANGUAGE.query('(signature _ type: _ _ @type)')
tqdm.pandas(desc='Progress')
signatures['docType'] = signatures['docItem'].progress_apply(lambda item: get_sig_type(item, query))
signatures
# tree = parser.parse(bytes(all_sigs, "utf8"))
# query = HS_LANGUAGE.query('(signature _ type: _ _ @type)')
# captures = query.captures(tree.root_node)
# types = pd.Series([str(ty[0].text, 'UTF-8') for ty in captures])
# signatures['docType'] = types
# signatures

# tree.root_node.children[0].children[3].text
# print(tree.root_node.sexp())
# Out:
# 470571
# Progress:  20%|██        | 95104/470571 [00:05<00:19, 18825.04it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14880/3760360832.py in <module>
#       3 query = HS_LANGUAGE.query('(signature _ type: _ _ @type)')
#       4 tqdm.pandas(desc='Progress')
# ----> 5 signatures['docType'] = signatures['docItem'].progress_apply(lambda item: get_sig_type(item, query))
#       6 signatures
#       7 # tree = parser.parse(bytes(all_sigs, "utf8"))
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\tqdm\std.py in inner(df, func, *args, **kwargs)
#     812                 # on the df using our wrapper (which provides bar updating)
#     813                 try:
# --> 814                     return getattr(df, df_function)(wrapper, **kwargs)
#     815                 finally:
#     816                     t.close()
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\pandas\core\apply.py in apply(self)
#    1080             return self.apply_str()
#    1081
# -> 1082         return self.apply_standard()
#    1083
#    1084     def agg(self):
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1135                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136                 # "Callable[[Any], Any]"
# -> 1137                 mapped = lib.map_infer(
#    1138                     values,
#    1139                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\tqdm\std.py in wrapper(*args, **kwargs)
#     806                     # on the first column/row to decide whether it can
#     807                     # take a fast or slow code path; so stop when t.total==t.n
# --> 808                     t.update(n=1 if not t.total or t.n < t.total else 0)
#     809                     return func(*args, **kwargs)
#     810
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\tqdm\std.py in update(self, n)
#    1239                     self._ema_dn(dn)
#    1240                     self._ema_dt(dt)
# -> 1241                 self.refresh(lock_args=self.lock_args)
#    1242                 if self.dynamic_miniters:
#    1243                     # If no `miniters` was specified, adjust automatically to the
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\tqdm\std.py in refresh(self, nolock, lock_args)
#    1344             else:
#    1345                 self._lock.acquire()
# -> 1346         self.display()
#    1347         if not nolock:
#    1348             self._lock.release()
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\tqdm\std.py in display(self, msg, pos)
#    1492         if pos:
#    1493             self.moveto(pos)
# -> 1494         self.sp(self.__str__() if msg is None else msg)
#    1495         if pos:
#    1496             self.moveto(-pos)
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\tqdm\std.py in print_status(s)
#     348         def print_status(s):
#     349             len_s = disp_len(s)
# --> 350             fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     351             last_len[0] = len_s
#     352
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\tqdm\std.py in fp_write(s)
#     341
#     342         def fp_write(s):
# --> 343             fp.write(_unicode(s))
#     344             fp_flush()
#     345
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\tqdm\utils.py in inner(*args, **kwargs)
#     143         def inner(*args, **kwargs):
#     144             try:
# --> 145                 return func(*args, **kwargs)
#     146             except OSError as e:
#     147                 if e.errno != 5:
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     527             is_child = (not self._is_master_process())
#     528             # only touch the buffer in the IO thread to avoid races
# --> 529             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     530             if is_child:
#     531                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     545                 )
#     546             data.group = group
# --> 547         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     548
#     549     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
signatures[signatures['docType'].str.len() == 1]
# Out:
#             docId                                         docContent  \
# 13037     2648492
# 13038     2648643
# 13039     2648794
# 13040     2648946
# 13041     2649096
# ...           ...                                                ...
# 654090  146307709
# 654099  146309293  The main configuration given in\n<a>https://de...
# 654100  146309505  The main configuration given in\n<a>https://en...
# 659799  147622282  A special error value. If a property evaluates...
# 745381  166909177
#
#                     docItem docType                docPackage  is_signature
# 13037       bankSelect :: T       T                      midi          True
# 13038       modulation :: T       T                      midi          True
# 13039    breathControl :: T       T                      midi          True
# 13040      footControl :: T       T                      midi          True
# 13041   portamentoTime :: T       T                      midi          True
# ...                     ...     ...                       ...           ...
# 654090           empty :: T       T  battleship-combinatorics          True
# 654099          german :: T       T  battleship-combinatorics          True
# 654100         english :: T       T  battleship-combinatorics          True
# 659799         discard :: a       a          tasty-quickcheck          True
# 745381      anchorDown :: Y       Y                LambdaHack          True
#
# [617 rows x 6 columns]

# %%
signatures[6]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\sbert-ts\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 6
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14880/225507644.py in <module>
# ----> 1 signatures[6]
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\envs\sbert-ts\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 6

# %%
tree = parser.parse(bytes(""":: Radians x => Radians x -> Degrees x""", "utf8"))
print(tree.root_node.sexp())
tree.root_node.children[0].children[2].text
# query = HS_LANGUAGE.query("(signature _ _ _ @type)")
# cap = query.captures(tree.root_node)
# cap[0][0].text
# print(len(cap[0]))
# print(cap[0])
# Out:
# Radians x => Radians x -> Degrees x
# (haskell (signature name: (variable (MISSING _varid)) type: (context (constraint class: (class_name (type)) (type_name (type_variable))) (fun (type_apply (type_name (type)) (type_name (type_variable))) (type_apply (type_name (type)) (type_name (type_variable)))))))
# b'Radians x => Radians x -> Degrees x'

# %%
tree = parser.parse(bytes("""( ## ) :: Diagram -> Diagram -> Diagram""", "utf8"))
print(tree.root_node.sexp())
q = HS_LANGUAGE.query('(signature name: )')
cap = q.captures(tree.root_node)
print(cap[0][0].text)
# Out:
# (haskell (signature name: (operator) type: (fun (type_name (type)) (fun (type_name (type)) (type_name (type))))))
# b')'
